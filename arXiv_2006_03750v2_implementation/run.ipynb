# %%
from generate_graph import create_graph_dataset
import torch
from main import train

# %%
train()
# Out:
# Model(
#   (gat): GAT(1, 1, num_layers=3)
# )
# Batch(edge_index=[2, 12], weight=[12], num_nodes=5, batch=[5], ptr=[2])
# Batch(edge_index=[2, 24], features=[6], num_nodes=6, batch=[6], ptr=[2], x=[6, 1])
# Batch(edge_index=[2, 6], weight=[6], num_nodes=5, batch=[5], ptr=[2])
# tensor([[0.1666],
#         [0.1662],
#         [0.1668],
#         [0.1669],
#         [0.1667],
#         [0.1668]], grad_fn=<SoftmaxBackward>)
# tensor([3])
# tensor([1])
# tensor([0])
# tensor([1])
# tensor([0])
# tensor([1])

# %%
a = torch.tensor([[1],[2],[3]])
print(a)
print(a.shape)
print(a.dim)

print(torch.sum(a,dim=0))
# Out:
# tensor([[1],
#         [2],
#         [3]])
# torch.Size([3, 1])
# <built-in method dim of Tensor object at 0x7fe1a40898c0>
# tensor([6])

# %%
from generate_graph import create_graph_dataset
import torch
from main import train

# %%
train()
# Out:
# Batch(edge_index=[2, 14], weight=[14], num_nodes=5, batch=[5], ptr=[2])
# Batch(edge_index=[2, 30], features=[7], num_nodes=7, batch=[7], ptr=[2])
# Batch(edge_index=[2, 8], weight=[8], num_nodes=5, batch=[5], ptr=[2])
